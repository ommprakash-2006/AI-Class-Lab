# %% [markdown]
# <a href="https://colab.research.google.com/github/ommprakash-2006/AI-Class-Lab/blob/main/AI_Lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# **Introduction Program**

# %%
name = input("Enter your name: ")
branch = input("Enter your branch: ")

print("Welcome",name)
print("Branch:",branch)
print("Hey! You are learning Artificial Interlligence.")
# Out:
# Enter your name: Omm Prakash
# Enter your branch: CSE(AIML)
# Welcome Omm Prakash
# Branch: CSE(AIML)
# Hey! You are learning Artificial Interlligence.

# %% [markdown]
# **Even Odd Check**

# %%
num = input("Enter a number: ")
num = int(num)

if num%2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Enter a number: 9
# Odd

# %% [markdown]
# **AI Calculator**

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

print("Addition = ",a+b)
print("Substraction = ",a-b)
print("Multiplication = ",a*b)
print("Division = ",a/b)
# Out:
# Enter first number: 7
# Enter second number: 4
# Addition =  11
# Substraction =  3
# Multiplication =  28
# Division =  1.75

# %% [markdown]
# **Guessing Game**

# %%
secret = 7
guess = int(input("Guess a number: "))

if guess == secret:
  print("Correct")
else:
  print("Wrong")
# Out:
# Guess a number: 2
# Wrong

# %% [markdown]
# **1. Write a program to implement BFS**
#
# **AIM :** To implement BFS using Python.
#
# **Theory :** Provide the concept, working principle, algorithm & applications before performing the experiment.
#
# **Algorithm :**
#
# 1. Start
# 2. Accept input
# 3. Execute the logic
# 4. Display the result
# 5. Stop
#
# **Python Program :**

# %%
from collections import deque

# BFS function
def bfs(graph, start):
    visited = set()
    queue = deque([start])

    visited.add(start)

    print("BFS Traversal:")

    while queue:
        vertex = queue.popleft()
        print(vertex, end=" ")

        for neighbor in graph[vertex]:
            if neighbor not in visited:
                visited.add(neighbor)
                queue.append(neighbor)

# Graph represented as an adjacency list
graph = {
    'A': ['B', 'C'],
    'B': ['D', 'E'],
    'C': ['F'],
    'D': [],
    'E': ['F'],
    'F': []
}

# Starting vertex
bfs(graph, 'A')
# Out:
# BFS Traversal:
# A B C D E F
